# %% [markdown]
# # Inspecting Data Types
# Use the space below to explore `data_08_v2.csv` and `data_18_v2.csv` to answer the quiz questions below regarding datatypes. You should've created these data files in the previous section: *Filter, Drop Nulls, Dedupe*.

# %%
# load the data
import pandas as pd

df_08 =  pd.read_csv('data_08_v2.csv')
df_18 =  pd.read_csv('data_18_v2.csv')

# %%
df_08.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
df_18.head(4)
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline  small SUV
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline  small SUV
# 2  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline  small car
# 3  ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline  small car
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No
# 1                    3       19      27      22                     4       No
# 2                    3       23      33      27                     6       No
# 3                    3       20      32      24                     5       No

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                      object
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score      object
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score     object
# smartway                 object
# dtype: object

# %%
df_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                     float64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
df_08.head(20)
# Out:
#                        model  displ       cyl    trans drive      fuel  \
# 0                  ACURA MDX    3.7   (6 cyl)  Auto-S5   4WD  Gasoline
# 1                  ACURA RDX    2.3   (4 cyl)  Auto-S5   4WD  Gasoline
# 2                   ACURA RL    3.5   (6 cyl)  Auto-S5   4WD  Gasoline
# 3                   ACURA TL    3.2   (6 cyl)  Auto-S5   2WD  Gasoline
# 4                   ACURA TL    3.5   (6 cyl)  Auto-S5   2WD  Gasoline
# 5                   ACURA TL    3.5   (6 cyl)    Man-6   2WD  Gasoline
# 6                  ACURA TSX    2.4   (4 cyl)    Man-6   2WD  Gasoline
# 7                  ACURA TSX    2.4   (4 cyl)  Auto-S5   2WD  Gasoline
# 8           ASTON MARTIN DB9    5.9  (12 cyl)    Man-6   2WD  Gasoline
# 9           ASTON MARTIN DB9    5.9  (12 cyl)  Auto-S6   2WD  Gasoline
# 10  ASTON MARTIN DB9 Volante    5.9  (12 cyl)    Man-6   2WD  Gasoline
# 11  ASTON MARTIN DB9 Volante    5.9  (12 cyl)  Auto-S6   2WD  Gasoline
# 12   ASTON MARTIN V8 Vantage    4.3   (8 cyl)    Man-6   2WD  Gasoline
# 13   ASTON MARTIN V8 Vantage    4.3   (8 cyl)  Auto-S6   2WD  Gasoline
# 14                   AUDI A3    2.0   (4 cyl)    Man-6   2WD  Gasoline
# 15                   AUDI A3    2.0   (4 cyl)  Auto-S6   2WD  Gasoline
# 16                   AUDI A3    3.2   (6 cyl)  Auto-S6   4WD  Gasoline
# 17                   AUDI A4    2.0   (4 cyl)  Auto-AV   2WD  Gasoline
# 18                   AUDI A4    3.1   (6 cyl)    Man-6   4WD  Gasoline
# 19                   AUDI A4    3.1   (6 cyl)  Auto-S6   4WD  Gasoline
#
#         veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0             SUV                   7       15      20      17
# 1             SUV                   7       17      22      19
# 2     midsize car                   7       16      24      19
# 3     midsize car                   7       18      26      21
# 4     midsize car                   7       17      26      20
# 5     midsize car                   7       18      27      21
# 6       small car                   6       19      28      22
# 7       small car                   6       20      28      23
# 8       small car                   6       10      16      12
# 9       small car                   6       11      18      13
# 10      small car                   6       10      16      12
# 11      small car                   6       11      17      13
# 12      small car                   6       12      19      15
# 13      small car                   6       13      20      15
# 14  station wagon                   7       21      29      24
# 15  station wagon                   7       22      29      25
# 16  station wagon                   6       18      25      21
# 17      small car                   7       21      30      24
# 18      small car                   6       15      25      19
# 19      small car                   6       17      25      20
#
#    greenhouse_gas_score smartway
# 0                     4       no
# 1                     5       no
# 2                     5       no
# 3                     6      yes
# 4                     6      yes
# 5                     6      yes
# 6                     6       no
# 7                     7      yes
# 8                     0       no
# 9                     1       no
# 10                    0       no
# 11                    1       no
# 12                    3       no
# 13                    3       no
# 14                    7      yes
# 15                    7      yes
# 16                    6       no
# 17                    7      yes
# 18                    5       no
# 19                    6       no

# %%
df_08.air_pollution_score.unique()
# Out:
# array(['7', '6', '9.5', '9', '6/4'], dtype=object)

# %%
df_18.air_pollution_score.unique()
# Out:
# array([3, 1, 7, 5, 6])

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score     object
# smartway                 object
# dtype: object

# %%
df_08.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
df_18.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                     float64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
greenhouse_gas_score
