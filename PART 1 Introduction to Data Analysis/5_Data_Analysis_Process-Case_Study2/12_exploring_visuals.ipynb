# %% [markdown]
# # Exploring with Visuals
# Use `clean_08.csv` and `clean_18.csv`. You should've created these data files in the previous section: *Fixing Data Types Pt 3*.

# %%
# load datasets
import pandas as pd

df_08 = pd.read_csv('clean_08.csv')
df_18 = pd.read_csv('clean_18.csv')

# %%
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 0  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  3.0      15.0     20.0     17.0                     5
#
#   smartway
# 0       No

# %% [markdown]
# ### QUESTION 1 OF 4
# Compare the distributions of greenhouse gas score in 2008 and 2018.

# %%
df_08['greenhouse_gas_score'].hist(figsize=(10, 5), bins=15);

# %%
df_18['greenhouse_gas_score'].hist(figsize=(10, 5), bins=15);

# %% [markdown]
# ### QUESTION 2 OF 4
# How has the distribution of combined mpg changed from 2008 to 2018?

# %%
df_08['cmb_mpg'].hist(figsize=(10, 5), bins=5);

# %%
df_18['cmb_mpg'].hist(figsize=(10, 5), bins=5);

# %% [markdown]
# ### QUESTION 3 OF 4
# Describe the correlation between displacement and combined mpg.

# %%
df_08.plot(x='displ', y='cmb_mpg', kind='scatter')

# %%
df_18.plot(x='displ', y='cmb_mpg', kind='scatter')

# %% [markdown]
# #### QUESTION 4 OF 4
# Describe the correlation between greenhouse gas score and combined mpg.

# %%
df_08.plot(x='greenhouse_gas_score', y='cmb_mpg', kind='scatter');

# %%
df_18.plot(x='greenhouse_gas_score', y='cmb_mpg', kind='scatter');
